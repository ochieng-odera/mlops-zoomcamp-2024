# %% [markdown]
# ## Homework 2 - Experiment Tracking

# %% [markdown]
# MLflow setup:
# - tracking server: yes, local server. You can also use a remote server
# - backend store: postgres database
# - artifacts store: local filesystem . You can also use s3 bucket

# %% [markdown]
# To run this notebook you need to launch the mlflow server locally by running the following command in your terminal:
#
# `mlflow server --backend-store-uri postgresql://mlflow_user:test123@0.0.0.0:5432/mlflow`

# %% [markdown]
# ### Q1. Install MLflow

# %%
print(mlflow.__version__)
# Out:
# 2.11.3

# %% [markdown]
# ### Q2. Download and preprocess the data

# %%
# !python preprocess_data.py --raw_data_path data --dest_path ./output
# !ls ./output | wc -l
# Out:
#        4

# %% [markdown]
# ### Q3. Train a model with autolog

# %%
# !python train.py --data_path ./output
# Out:
# 2024/05/27 17:37:21 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2024/05/27 17:37:22 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2024/05/27 17:37:22 INFO mlflow.store.db.utils: Updating database tables
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# 2024/05/27 17:37:22 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2024/05/27 17:37:22 INFO mlflow.store.db.utils: Updating database tables
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# Traceback (most recent call last):
#   File "/Users/billehsarkozy/anaconda3/envs/mlops/lib/python3.12/site-packages/alembic/script/base.py", line 251, in _catch_revision_errors
#     yield
# ...

# %% [markdown]
# ### Q4. Launch the tracking server locally

# %%
# !mlflow ui --backend-store-uri sqlite:///mlflow.db --default-artifact-root ./artifacts
# Out:
# 2024/05/27 17:37:24 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2024/05/27 17:37:24 INFO mlflow.store.db.utils: Updating database tables
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# 2024/05/27 17:37:24 ERROR mlflow.cli: Error initializing backend store
# 2024/05/27 17:37:24 ERROR mlflow.cli: Can't locate revision identified by '867495a8f9d4'
# Traceback (most recent call last):
#   File "/Users/billehsarkozy/anaconda3/envs/mlops/lib/python3.12/site-packages/alembic/script/base.py", line 251, in _catch_revision_errors
#     yield
#   File "/Users/billehsarkozy/anaconda3/envs/mlops/lib/python3.12/site-packages/alembic/script/base.py", line 459, in _upgrade_revs
#     for script in reversed(list(revs))
#                            ^^^^^^^^^^
# ...

# %% [markdown]
# ### Q5. Tune model hyperparameters

# %%
# !python hpo.py
# Out:
# 2024/05/27 17:39:57 INFO mlflow.tracking.fluent: Experiment with name 'random-forest-hyperopt' does not exist. Creating a new experiment.
#   0%|                                    | 0/15 [00:00<?, ?trial/s, best loss=?]/Users/billehsarkozy/anaconda3/envs/mlops/lib/python3.12/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
#   7%|▋          | 1/15 [00:06<01:36,  6.93s/trial, best loss: 5.370086069268862]job exception: INVALID_PARAMETER_VALUE: Changing param values is not allowed. Params were already logged='[{'key': 'max_depth', 'old_value': '13', 'new_value': '2'}, {'key': 'n_estimators', 'old_value': '43', 'new_value': '22'}]' for run ID='99336a7dd7d64d7bac01e56e9f4c781a'.
#
#   7%|▋          | 1/15 [00:06<01:37,  6.96s/trial, best loss: 5.370086069268862]
# Traceback (most recent call last):
# ...

# %% [markdown]
# ### Q6. Promote the best model to the model registry

# %%
# !python register_model.py

# %% [markdown]
# ---
